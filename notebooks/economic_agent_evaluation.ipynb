# %% [markdown]
# # AI Economic Agent Evaluation
# Benchmarking reliability on economic and business reasoning tasks.

# %%
from src.benchmark import build_benchmark
benchmark = build_benchmark()
benchmark
